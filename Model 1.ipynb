# %% [markdown]
# Section 1: Importing required functions and libraries

# %%
import pandas as pd
import numpy as np
import datetime
import requests
import json
import random
import sqlite3
from sklearn.model_selection import train_test_split
from statsmodels.formula.api import ols
import itertools

# %% [markdown]
# Section 2: Connecting to the dataset via API

# %%
api = "https://data.cityofnewyork.us/resource/qgea-i56i.json"
response_api = requests.get(api)
data = response_api.text
raw = json.loads(data)
df = pd.DataFrame.from_records(raw)
df.head(5)
# Out:
#   cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm addr_pct_cd  \
# 0  506547392  2018-03-29T00:00:00.000     20:30:00          32
# 1  629632833  2018-02-06T00:00:00.000     23:15:00          52
# 2  787203902  2018-11-21T00:00:00.000     00:15:00          75
# 3  280364018  2018-06-09T00:00:00.000     21:42:00          10
# 4  985800320  2018-11-10T00:00:00.000     19:40:00          19
#
#                     rpt_dt ky_cd                       ofns_desc pd_cd  \
# 0  2018-03-30T00:00:00.000   351  CRIMINAL MISCHIEF & RELATED OF   254
# 1  2018-02-07T00:00:00.000   341                   PETIT LARCENY   333
# 2  2018-11-21T00:00:00.000   341                   PETIT LARCENY   321
# 3  2018-06-10T00:00:00.000   361   OFF. AGNST PUB ORD SENSBLTY &   639
# 4  2018-11-10T00:00:00.000   341                   PETIT LARCENY   333
#
#                           pd_desc crm_atpt_cptd_cd  ... susp_age_group  \
# 0  MISCHIEF, CRIMINAL 4, OF MOTOR        COMPLETED  ...            NaN
# 1  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  ...          45-64
# 2         LARCENY,PETIT FROM AUTO        COMPLETED  ...          25-44
# 3         AGGRAVATED HARASSMENT 2        COMPLETED  ...          25-44
# 4  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  ...            <18
#
#         susp_race susp_sex             cmplnt_to_dt cmplnt_to_tm  \
# 0             NaN      NaN                      NaN          NaN
# 1           BLACK        F                      NaN          NaN
# 2  WHITE HISPANIC        F  2018-11-21T00:00:00.000     00:20:00
# 3  WHITE HISPANIC        M  2018-06-09T00:00:00.000     21:43:00
# 4  BLACK HISPANIC        F  2018-11-10T00:00:00.000     19:45:00
#
#   transit_district station_name parks_nm housing_psa hadevelopt
# 0              NaN          NaN      NaN         NaN        NaN
# 1              NaN          NaN      NaN         NaN        NaN
# 2              NaN          NaN      NaN         NaN        NaN
# 3              NaN          NaN      NaN         NaN        NaN
# 4              NaN          NaN      NaN         NaN        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# Section 3: Counting the number of occurrences of crimes per day and cleaning up dataframe

# %%
counting = df.groupby(['boro_nm','cmplnt_fr_dt']).size().reset_index(name='count')
df_count = pd.merge(df,counting,how='right',on=['boro_nm','cmplnt_fr_dt'])
#df_count['sex_coded'] = pd.factorize(df.susp_sex)[0]
#df_count['age_coded'] = pd.factorize(df.susp_age_group)[0]
df_count['weekday'] = df_count['cmplnt_fr_dt'].apply(lambda x: pd.to_datetime(x).weekday())

df_count['susp_sex'] = df_count['susp_sex'].fillna('U')
df_count['susp_age_group'] = df_count['susp_age_group'].fillna('UNKNOWN')
df_count['boro_nm'] = df_count['boro_nm'].fillna('no_name')
df_count['susp_race'] = df_count['susp_race'].fillna('UNKNOWN')
# Out:
# 0             UNKNOWN
# 1             UNKNOWN
# 2             UNKNOWN
# 3      WHITE HISPANIC
# 4             UNKNOWN
#             ...
# 995             BLACK
# 996             BLACK
# 997             BLACK
# 998           UNKNOWN
# 999           UNKNOWN
# Name: susp_race, Length: 1000, dtype: object

# %% [markdown]
# Section 4: Splitting into test, train, and validation sets

# %%
df_range = list(range(0,len(df)))
random.shuffle(df_range)
train = df_range[0:799]
test = df_range[800:899]
validate = df_range[900:1000]
train_df = df_count.iloc[train]
test_df = df_count.iloc[test]
validate_df = df_count.iloc[test]

# %% [markdown]
# Section 5: FItting and displaying model summary and accuracy

# %%
fit = ols('count~C(susp_sex)+C(susp_age_group)+C(weekday)+C(boro_nm)+C(susp_race)',data=train_df).fit()
print(fit.summary())
predictions = round(fit.predict(test_df))#.fillna(0)
count=0
for true,predicted in zip(test_df['count'],predictions):
    if true == predicted:
        count+=1
accuracy = count/len(predictions)
accuracy
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.938
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):            0.00537
# Time:                        19:44:08   Log-Likelihood:                -912.87
# No. Observations:                 799   AIC:                             1874.
# Df Residuals:                     775   BIC:                             1986.
# Df Model:                          23
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    1.8531      0.569      3.256      0.001       0.736       2.970
# C(susp_sex)[T.M]                            -0.1310      0.084     -1.559      0.119      -0.296       0.034
# C(susp_sex)[T.U]                            -0.1244      0.142     -0.877      0.381      -0.403       0.154
# C(susp_age_group)[T.25-44]                  -0.0307      0.116     -0.264      0.792      -0.259       0.198
# C(susp_age_group)[T.45-64]                  -0.0695      0.134     -0.520      0.603      -0.332       0.193
# C(susp_age_group)[T.65+]                     0.3971      0.335      1.185      0.236      -0.261       1.055
# C(susp_age_group)[T.<18]                     0.3685      0.207      1.777      0.076      -0.038       0.775
# C(susp_age_group)[T.UNKNOWN]                -0.0638      0.132     -0.484      0.629      -0.323       0.195
# C(weekday)[T.1]                              0.0954      0.109      0.872      0.384      -0.119       0.310
# C(weekday)[T.2]                              0.1826      0.102      1.786      0.074      -0.018       0.383
# C(weekday)[T.3]                              0.2299      0.104      2.206      0.028       0.025       0.434
# C(weekday)[T.4]                              0.2622      0.099      2.642      0.008       0.067       0.457
# C(weekday)[T.5]                              0.1379      0.102      1.352      0.177      -0.062       0.338
# C(weekday)[T.6]                              0.1386      0.106      1.311      0.190      -0.069       0.346
# C(boro_nm)[T.BROOKLYN]                       0.1614      0.078      2.063      0.039       0.008       0.315
# C(boro_nm)[T.MANHATTAN]                      0.1395      0.080      1.748      0.081      -0.017       0.296
# C(boro_nm)[T.QUEENS]                         0.0156      0.090      0.174      0.862      -0.160       0.192
# C(boro_nm)[T.STATEN ISLAND]                 -0.4326      0.171     -2.532      0.012      -0.768      -0.097
# C(susp_race)[T.ASIAN / PACIFIC ISLANDER]    -0.5979      0.573     -1.043      0.297      -1.724       0.528
# C(susp_race)[T.BLACK]                       -0.2956      0.555     -0.533      0.594      -1.385       0.794
# C(susp_race)[T.BLACK HISPANIC]              -0.3287      0.575     -0.571      0.568      -1.458       0.801
# C(susp_race)[T.UNKNOWN]                     -0.2675      0.563     -0.475      0.635      -1.373       0.838
# C(susp_race)[T.WHITE]                       -0.2528      0.562     -0.450      0.653      -1.356       0.851
# C(susp_race)[T.WHITE HISPANIC]              -0.1705      0.557     -0.306      0.759      -1.264       0.923
# ==============================================================================
# Omnibus:                       72.880   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.328
# Skew:                           0.833   Prob(JB):                     8.94e-21
# Kurtosis:                       2.987   Cond. No.                         83.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.29292929292929293
